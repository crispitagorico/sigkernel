# %%
# !git clone 'https://github.com/crispitagorico/SignatureKernel.git'
# Out:
# Cloning into 'SignatureKernel'...
# remote: Enumerating objects: 418, done.
# remote: Counting objects: 100% (418/418), done.
# remote: Compressing objects: 100% (280/280), done.
# remote: Total 418 (delta 198), reused 335 (delta 123), pack-reused 0
# Receiving objects: 100% (418/418), 16.88 MiB | 27.21 MiB/s, done.
# Resolving deltas: 100% (198/198), done.

# %%
# !pip install iisignature
# !pip install esig
# !pip install tslearn
# Out:
# Requirement already satisfied: iisignature in /usr/local/lib/python3.6/dist-packages (0.24)
# Requirement already satisfied: numpy>1.7 in /usr/local/lib/python3.6/dist-packages (from iisignature) (1.18.5)
# Requirement already satisfied: esig in /usr/local/lib/python3.6/dist-packages (0.8.2)
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.6/dist-packages (from esig) (1.18.5)
# Requirement already satisfied: tslearn in /usr/local/lib/python3.6/dist-packages (0.4.1)
# Requirement already satisfied: Cython in /usr/local/lib/python3.6/dist-packages (from tslearn) (0.29.21)
# Requirement already satisfied: numba in /usr/local/lib/python3.6/dist-packages (from tslearn) (0.48.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from tslearn) (1.18.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.6/dist-packages (from tslearn) (0.22.2.post1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from tslearn) (1.4.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.6/dist-packages (from tslearn) (0.17.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from numba->tslearn) (50.3.2)
# Requirement already satisfied: llvmlite<0.32.0,>=0.31.0dev0 in /usr/local/lib/python3.6/dist-packages (from numba->tslearn) (0.31.0)

# %%
% cd /content/SignatureKernel/src/
# Out:
# /content/SignatureKernel/src

# %%
# !python setup.py build_ext --inplace
# Out:
# running build_ext
# copying build/lib.linux-x86_64-3.6/sigKer_fast.cpython-36m-x86_64-linux-gnu.so ->

# %%
# %cd /content/SignatureKernel/Dilate_loss/
# Out:
# /content/SignatureKernel/Dilate_loss

# %%
import numpy as np
import torch
import random
import matplotlib.pyplot as plt
import warnings
import warnings; warnings.simplefilter('ignore')
from mpl_toolkits.mplot3d import Axes3D

from data.synthetic_dataset import create_synthetic_dataset, SyntheticDataset, SyntheticDatasetMultivariate
from models.seq2seq import EncoderRNN, DecoderRNN, Net_GRU
from torch.utils.data import DataLoader
from tslearn.metrics import dtw, dtw_path

# from loss.dilate_loss import dilate_loss
from loss.sDTW import SoftDTW

import sys
sys.path.append('../')
sys.path.append('../src')
from utils.tools import brownian, Lorenz
from src.sigKer_torch import SigLoss, SigLoss_naive
from src.sigKerHom_torch import SigLossHom

# %%
import matplotlib.animation as animation

# %%
def rcos(t):
#     a = np.random.uniform(1,1.2)
    a = 0.5
    return t*np.cos(a*t)
def rsin(t):
#     b = np.random.uniform(1,1.2)
    b = 0.5
    return t*np.sin(b*t)

def generate_curve(N, L=100, T=5*np.pi):
    t = np.linspace(0,T,L)[:,None]
    return 1/T*np.array([np.concatenate([t,rcos(t),rsin(t)], axis=1) for k in range(N)])

# %%
dtype = torch.float64
device = torch.device("cpu")
# device = torch.device("cuda:0") # Uncomment this to run on GPU
a  = 1.5
b = -2.4
T_y = 100
T_x = 100

y = torch.tensor(generate_curve(1,T_y,10*np.pi), device=device, dtype=dtype, requires_grad=False)

# %%
data = []

# %%
learning_rate = 1e-1

x = torch.tensor(np.zeros((1,T_x,3)), device=device, dtype=dtype,requires_grad=True)

optimizer = torch.optim.Adam([x], lr=learning_rate)

losses = []

for t in range(1000):

#     criterion = torch.nn.MSELoss()
#     criterion = SoftDTW(gamma=0.001, normalize=True)
    criterion = SigLoss(n=0, n_chunks=3)
    loss = criterion(x,y)    
    
    if t % 10 == 0:
        # fig = plt.figure(figsize=(8,6))
        # ax = fig.gca(projection='3d')
        # ax.plot(x.detach().numpy()[0,:,0],x.detach().numpy()[0,:,1],x.detach().numpy()[0,:,2], label='pred')
        # ax.plot(y.detach().numpy()[0,:,0],y.detach().numpy()[0,:,1],y.detach().numpy()[0,:,2], label='true')
        # ax.set_xlabel('x')
        # ax.set_ylabel('y')
        # ax.set_zlabel('z')
        # plt.legend()
        # plt.show()
        data.append(x.detach().numpy().copy())

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
    losses.append(loss.item())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-60-bc4ae4fbed2b> in <module>()
#      12 #     criterion = SoftDTW(gamma=0.001, normalize=True)
#      13     criterion = SigLoss(n=0, n_chunks=3)
# ---> 14     loss = criterion(x,y)
#      15
#      16     if t % 10 == 0:
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# /content/SignatureKernel/src/sigKer_torch.py in forward(self, X, Y)
#      27             Y_chunks = torch.chunk(Y, k, dim=1)
#      28             for x1,x2,y1,y2 in zip(X_chunks[:-1], X_chunks[1:], Y_chunks[:-1], Y_chunks[1:]):
# ---> 29                 dist += self.sig_distance(torch.cat([x1,x2],dim=1),torch.cat([y1,y2],dim=1))
#      30
#      31         return dist
#
# /content/SignatureKernel/src/sigKer_torch.py in sig_distance(self, x, y)
#      14
#      15     def sig_distance(self,x,y):
# ---> 16         d = torch.mean(SigKernel.apply(x,None,self.n,self.method) + SigKernel.apply(y,None,self.n,self.method)- 2.*SigKernel.apply(x,y,self.n,self.method) )
#      17         return d #+ torch.mean((x[:,0,:]-y[:,0,:])**2) #+ torch.mean(torch.abs(x[:,-1,:]-y[:,-1,:]))
#      18
#
# /content/SignatureKernel/src/sigKer_torch.py in forward(ctx, X, Y, n, method)
#      73         if XX or XY:
#      74             if method=='variation_parameters':
# ---> 75                 K, K_rev = sig_kernel_batch(X.detach().cpu().numpy(),Y.detach().cpu().numpy(),n=n,gradients=True)
#      76             else:
#      77                 K, K_rev = sig_kernel_batch_(X.detach().cpu().numpy(),Y.detach().cpu().numpy(),n=n,gradients=True)
#
# KeyboardInterrupt:

# %%
plt.plot(losses)

# %%
Writer = animation.writers['ffmpeg']
writer = Writer(fps=5, metadata=dict(artist='Me'), bitrate=1800)

# %%
def animate(i):
  ax.clear()
  ax.plot(data[i][0,:,0],data[i][0,:,1],data[i][0,:,2], label='pred')
  ax.plot(y.detach().numpy()[0,:,0],y.detach().numpy()[0,:,1],y.detach().numpy()[0,:,2], label='true')

# %%
fig = plt.figure(figsize=(8,6))
ax = fig.gca(projection='3d')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
plt.legend()

ani = animation.FuncAnimation(fig, animate, frames=30, repeat=True, blit=False)
# Out:
# No handles with labels found to put in legend.

# %%
ani.save('video.mp4', writer=writer)

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
random.seed(0)

# %%
# parameters
batch_size = 10
N = 100 # number of time series
N_input = 50 # number of input time steps
N_output = 50  # number of time steps to predict

# %%
X_train = 0.1*generate_curve(N, N_input+N_output,10*np.pi)
X_test = 0.1*generate_curve(N, N_input+N_output,10*np.pi)

# %%
x = X_train[0]

# %%
fig = plt.figure(figsize=(8,6))
ax = fig.gca(projection='3d')
ax.plot(x[:,0],x[:,1],x[:,2], label='path')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
plt.legend()
plt.show()

# %%
X_train_input = torch.tensor(X_train[:,:N_input,:], dtype=torch.float64)
X_train_target = torch.tensor(X_train[:,N_input:,:], dtype=torch.float64)
X_test_input = torch.tensor(X_test[:,:N_input,:], dtype=torch.float64)
X_test_target = torch.tensor(X_test[:,N_input:,:], dtype=torch.float64)

# %%
# Make datasets
# dataset_train = SyntheticDataset(X_train_input,X_train_target, train_bkp)
# dataset_test  = SyntheticDataset(X_test_input,X_test_target, test_bkp)
dataset_train = SyntheticDatasetMultivariate(X_train_input, X_train_target)
dataset_test  = SyntheticDatasetMultivariate(X_test_input, X_test_target)
trainloader = DataLoader(dataset_train, batch_size=batch_size, shuffle=True, num_workers=1)
testloader  = DataLoader(dataset_test, batch_size=batch_size, shuffle=False, num_workers=1)

# %%
def train_model(net, loss_type, learning_rate, epochs=1000, print_every=50, eval_every=50, 
                gamma=0.001, alpha=0.5):
    
    optimizer = torch.optim.Adam(net.parameters(), lr=learning_rate)
    
    for epoch in range(epochs): 
        for i, data in enumerate(trainloader, 0):

            inputs, target = data
            inputs = torch.tensor(inputs, dtype=torch.float64).to(device)
            target = torch.tensor(target, dtype=torch.float64).to(device)
            batch_size, N_output = target.shape[0:2]                     

            outputs = net(inputs)
            
            if loss_type=='mse':
                criterion = torch.nn.MSELoss()
                loss = criterion(target,outputs)
            
            elif loss_type=='soft-dtw':
                criterion = SoftDTW(gamma=gamma, normalize=True)
                loss = criterion(target,outputs).mean()
                
            elif loss_type=='signature':
                criterion = SigLoss(n=0, n_chunks=1)
                loss = criterion(target,outputs).mean()
                
            else:    
                loss, loss_shape, loss_temporal = dilate_loss(target, outputs, alpha, gamma, device)             
                  
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()          

        if (epoch % print_every == 0):
            print('epoch=', epoch, ' loss type=', loss_type, ' loss=', np.round(loss.item(),4))
        if (epoch % eval_every == 0):
          if loss_type=='signature':
            eval_model(net, testloader)
          else:
            eval_model(net, testloader,False)

# %%
def eval_model(net, loader, sig=True):   
        
    losses_mse = []

    for i, data in enumerate(loader, 0):
        
        loss_mse = torch.tensor(0,dtype=torch.float64)
        
        inputs, target = data
        inputs = torch.tensor(inputs, dtype=torch.float64).to(device)
        target = torch.tensor(target, dtype=torch.float64).to(device)
        batch_size, N_output = target.shape[0:2]
        
        outputs = net(inputs)
         
        # MSE    
        loss_mse = torch.nn.MSELoss()(target,outputs)    
        losses_mse.append(loss_mse.item())

    k = 0
    inp = inputs.detach().cpu().numpy()[k]
    x = outputs.detach().cpu().numpy()[k]
    y = target.detach().cpu().numpy()[k]
    if sig:
      x += y[0,:] - x[0,:]
    fig = plt.figure(figsize=(8,6))
    ax = fig.gca(projection='3d')
    ax.plot(inp[:,0],inp[:,1],inp[:,2], label='input')
    ax.plot(x[:,0],x[:,1],x[:,2], label='prediction')
    ax.plot(y[:,0],y[:,1],y[:,2], label='target')
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_zlabel('z')
    plt.legend()
    plt.show()
        
    print('test-mse=', np.round(np.array(losses_mse).mean(),4))

# %%
encoder = EncoderRNN(input_size=3, hidden_size=8, num_grulstm_layers=1, batch_size=batch_size).double().to(device)
decoder = DecoderRNN(input_size=3, hidden_size=8, num_grulstm_layers=1, fc_units=4, output_size=3).double().to(device)
net_gru_mse = Net_GRU(encoder, decoder, N_output, device).double().to(device)
train_model(net_gru_mse, loss_type='mse', learning_rate=0.001, epochs=500, print_every=20, eval_every=20)
# Out:
# epoch= 0  loss type= mse  loss= 0.0258
# test-mse= 0.0243
# epoch= 20  loss type= mse  loss= 0.0019
# test-mse= 0.0019
# epoch= 40  loss type= mse  loss= 0.0019
# test-mse= 0.0019
# epoch= 60  loss type= mse  loss= 0.0018
# test-mse= 0.0018
# epoch= 80  loss type= mse  loss= 0.0013
# test-mse= 0.0013
# epoch= 100  loss type= mse  loss= 0.0006
# test-mse= 0.0006
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-107-097f27c7b9b2> in <module>()
#       2 decoder = DecoderRNN(input_size=3, hidden_size=8, num_grulstm_layers=1, fc_units=4, output_size=3).double().to(device)
#       3 net_gru_mse = Net_GRU(encoder, decoder, N_output, device).double().to(device)
# ----> 4 train_model(net_gru_mse, loss_type='mse', learning_rate=0.001, epochs=500, print_every=20, eval_every=20)
#
# <ipython-input-100-f962bb5d24d2> in train_model(net, loss_type, learning_rate, epochs, print_every, eval_every, gamma, alpha)
#      30
#      31             optimizer.zero_grad()
# ---> 32             loss.backward()
#      33             optimizer.step()
#      34
#
# /usr/local/lib/python3.6/dist-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     219                 retain_graph=retain_graph,
#     220                 create_graph=create_graph)
# --> 221         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     222
#     223     def register_hook(self, hook):
#
# /usr/local/lib/python3.6/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#     130     Variable._execution_engine.run_backward(
#     131         tensors, grad_tensors_, retain_graph, create_graph,
# --> 132         allow_unreachable=True)  # allow_unreachable flag
#     133
#     134
#
# KeyboardInterrupt:

# %%
encoder = EncoderRNN(input_size=3, hidden_size=8, num_grulstm_layers=1, batch_size=batch_size).double().to(device)
decoder = DecoderRNN(input_size=3, hidden_size=8, num_grulstm_layers=1, fc_units=4, output_size=3).double().to(device)
net_gru_sdtw = Net_GRU(encoder, decoder, N_output, device).double().to(device)
train_model(net_gru_sdtw, loss_type='soft-dtw', learning_rate=0.001, epochs=1000, print_every=5, eval_every=5)
# Out:
# epoch= 0  loss type= soft-dtw  loss= 22.5573
# test-mse= 0.147
# epoch= 5  loss type= soft-dtw  loss= 5.2848
# test-mse= 0.0333
# epoch= 10  loss type= soft-dtw  loss= 0.7564
# test-mse= 0.0044
# epoch= 15  loss type= soft-dtw  loss= 0.3456
# test-mse= 0.0019
# epoch= 20  loss type= soft-dtw  loss= 0.3348
# test-mse= 0.0019
# epoch= 25  loss type= soft-dtw  loss= 0.333
# test-mse= 0.0019
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-108-04a70195d5e7> in <module>()
#       2 decoder = DecoderRNN(input_size=3, hidden_size=8, num_grulstm_layers=1, fc_units=4, output_size=3).double().to(device)
#       3 net_gru_sdtw = Net_GRU(encoder, decoder, N_output, device).double().to(device)
# ----> 4 train_model(net_gru_sdtw, loss_type='soft-dtw', learning_rate=0.001, epochs=1000, print_every=5, eval_every=5)
#
# <ipython-input-100-f962bb5d24d2> in train_model(net, loss_type, learning_rate, epochs, print_every, eval_every, gamma, alpha)
#       5
#       6     for epoch in range(epochs):
# ----> 7         for i, data in enumerate(trainloader, 0):
#       8
#       9             inputs, target = data
#
# /usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     433         if self._sampler_iter is None:
#     434             self._reset()
# --> 435         data = self._next_data()
#     436         self._num_yielded += 1
#     437         if self._dataset_kind == _DatasetKind.Iterable and \
#
# /usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#    1055                 # no valid `self._rcvd_idx` is found (i.e., didn't break)
#    1056                 if not self._persistent_workers:
# -> 1057                     self._shutdown_workers()
#    1058                 raise StopIteration
#    1059
#
# /usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py in _shutdown_workers(self)
#    1175                         self._mark_worker_as_unavailable(worker_id, shutdown=True)
#    1176                 for w in self._workers:
# -> 1177                     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#    1178                     if w.is_alive():
#    1179                         # Existing mechanisms try to make the workers exit
#
# /usr/lib/python3.6/multiprocessing/process.py in join(self, timeout)
#     122         assert self._parent_pid == os.getpid(), 'can only join a child process'
#     123         assert self._popen is not None, 'can only join a started process'
# --> 124         res = self._popen.wait(timeout)
#     125         if res is not None:
#     126             _children.discard(self)
#
# /usr/lib/python3.6/multiprocessing/popen_fork.py in wait(self, timeout)
#      45             if timeout is not None:
#      46                 from multiprocessing.connection import wait
# ---> 47                 if not wait([self.sentinel], timeout):
#      48                     return None
#      49             # This shouldn't block if wait() returned successfully.
#
# /usr/lib/python3.6/multiprocessing/connection.py in wait(object_list, timeout)
#     909
#     910             while True:
# --> 911                 ready = selector.select(timeout)
#     912                 if ready:
#     913                     return [key.fileobj for (key, events) in ready]
#
# /usr/lib/python3.6/selectors.py in select(self, timeout)
#     374             ready = []
#     375             try:
# --> 376                 fd_event_list = self._poll.poll(timeout)
#     377             except InterruptedError:
#     378                 return ready
#
# KeyboardInterrupt:

# %%
encoder = EncoderRNN(input_size=3, hidden_size=8, num_grulstm_layers=1, batch_size=batch_size).double().to(device)
decoder = DecoderRNN(input_size=3, hidden_size=8, num_grulstm_layers=1, fc_units=4, output_size=3).double().to(device)
net_gru_sig = Net_GRU(encoder, decoder, N_output, device).double().to(device)
train_model(net_gru_sig, loss_type='signature', learning_rate=0.5, epochs=500, print_every=5, eval_every=5)
# Out:
# epoch= 0  loss type= signature  loss= 0.0151
# test-mse= 6.565
# epoch= 5  loss type= signature  loss= 0.0151
# test-mse= 15.3653
# epoch= 10  loss type= signature  loss= 0.0151
# test-mse= 15.4553
# epoch= 15  loss type= signature  loss= 0.0151
# test-mse= 15.456
# epoch= 20  loss type= signature  loss= 0.0151
# test-mse= 15.456
# epoch= 25  loss type= signature  loss= 0.0151
# test-mse= 15.456
# epoch= 30  loss type= signature  loss= 0.0151
# test-mse= 15.456
# epoch= 35  loss type= signature  loss= 0.0151
# test-mse= 15.456
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-111-fbdad9227dcc> in <module>()
#       2 decoder = DecoderRNN(input_size=3, hidden_size=8, num_grulstm_layers=1, fc_units=4, output_size=3).double().to(device)
#       3 net_gru_sig = Net_GRU(encoder, decoder, N_output, device).double().to(device)
# ----> 4 train_model(net_gru_sig, loss_type='signature', learning_rate=0.5, epochs=500, print_every=5, eval_every=5)
#
# <ipython-input-100-f962bb5d24d2> in train_model(net, loss_type, learning_rate, epochs, print_every, eval_every, gamma, alpha)
#      12             batch_size, N_output = target.shape[0:2]
#      13
# ---> 14             outputs = net(inputs)
#      15
#      16             if loss_type=='mse':
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# /content/SignatureKernel/Dilate_loss/models/seq2seq.py in forward(self, x)
#      47         encoder_hidden = self.encoder.init_hidden(self.device)
#      48         for ei in range(input_length):
# ---> 49             encoder_output, encoder_hidden = self.encoder(x[:,ei:ei+1,:], encoder_hidden)
#      50
#      51         decoder_input = x[:,-1,:].unsqueeze(1) # first decoder input= last element of input sequence
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# /content/SignatureKernel/Dilate_loss/models/seq2seq.py in forward(self, input, hidden)
#      13
#      14     def forward(self, input, hidden): # input [batch_size, length T, dimensionality d]
# ---> 15         output, hidden = self.gru(input, hidden)
#      16         return output, hidden
#      17
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/rnn.py in forward(self, input, hx)
#     738         if batch_sizes is None:
#     739             result = _VF.gru(input, hx, self._flat_weights, self.bias, self.num_layers,
# --> 740                              self.dropout, self.training, self.bidirectional, self.batch_first)
#     741         else:
#     742             result = _VF.gru(input, batch_sizes, hx, self._flat_weights, self.bias,
#
# KeyboardInterrupt:

# %%
# Visualize results
gen_test = iter(testloader)
test_inputs, test_targets = next(gen_test)

test_inputs  = torch.tensor(test_inputs, dtype=torch.float64).to(device)
test_targets = torch.tensor(test_targets, dtype=torch.float64).to(device)
criterion = torch.nn.MSELoss()

nets = [net_gru_mse, net_gru_sdtw, net_gru_sig]
titles = ['mse loss', 'soft-dtw loss', 'signature loss']

# %%
for ind in range(batch_size):
     
    k = 1
    fig = plt.figure(figsize=(14,6))
    
    for net in nets:
        
        pred = net(test_inputs).to(device)

        input = test_inputs.detach().cpu().numpy()[ind,:,:]
        target = test_targets.detach().cpu().numpy()[ind,:,:]
        preds = pred.detach().cpu().numpy()[ind,:,:]
        
        ax = fig.add_subplot(1, 3, k, projection='3d')
#         ax.plot(input[:,0],input[:,1],input[:,2], label='input')
        # ax.plot(target[:,0],target[:,1],target[:,2], label='target')
        ax.plot(preds[:,0],preds[:,1],preds[:,2], label='prediction')
        ax.set_xlabel('x')
        ax.set_ylabel('y')
        ax.set_zlabel('z')
        ax.set_title(titles[k-1])
        plt.legend(loc='center left')
        k = k+1
    plt.show()
