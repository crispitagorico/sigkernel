# %%
import base

import numpy as np
import matplotlib.pyplot as plt

from sigKer_fast import mmd_distance

# %%
samples = 10
length_x = 100
length_y = 150
dim = 3

X = np.random.randn(samples,length_x,dim).cumsum(axis=1)
Y = np.random.randn(samples,length_y,dim).cumsum(axis=1)

X /= X.max()
Y /= Y.max()

# %%
X.shape
# Out:
# (10, 100, 3)

# %%
plt.plot(X[0])
plt.show()

# %%
mmd_distance(X,Y,n=0,rbf=True,sigma=1.)
# Out:
# 0.13901133961794443

# %% [markdown]
# $x:[0,T] \to \mathbb{R}^d$
#
# for any $t \in [0,T]$ you can apply the RBF feature map $\phi(x_t) = \exp(x_t)$
#
# $\phi(x) : [0,T] \to H$
#
# $$k(x,y) = <S(\phi(x)),S(\phi(y))>$$
