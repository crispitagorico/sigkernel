# %%
import base

import numpy as np
import matplotlib.pyplot as plt

# import iisignature
from sigKer_fast import mmd_distance

# %%
samples = 10
length_x = 100
length_y = 150
dim = 3

X = np.random.randn(samples,length_x,dim).cumsum(axis=1)
Y = np.random.randn(samples,length_y,dim).cumsum(axis=1)

X /= X.max()
Y /= Y.max()

# %%
X.shape
# Out:
# (10, 100, 3)

# %%
plt.plot(X[0])
plt.show()

# %%
mmd_distance(X,Y,n=0,solver=1,rbf=False,sigma=1.)
# Out:
# 0.1700082410448842

# %% [markdown]
# $x:[0,T] \to \mathbb{R}^d$
#
# for any $t \in [0,T]$ you can apply the RBF feature map $\phi(x_t) = \exp(x_t)$
#
# $$S(x) = \int ... \int dx^{(i_1)}_{t_1} ...dx^{(i_n)}_{t_n}$$
#
# $$k(x,y) = <S(x),S(y)>$$
#
# $$\frac{\partial^2 u}{\partial s \partial t} = \dot x_s^T \dot y_t u$$
